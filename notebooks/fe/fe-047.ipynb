# %%
import os
import re
import json
from collections import Counter
from datetime import datetime, timezone, timedelta
from pathlib import Path

import ipynbname
import polars as pl

# %% [markdown]
# ### Configuration

# %%
stem = ipynbname.path().stem
m = re.search(r"(\d+)$", stem)

ID = m.group(1)
SEED = 42
level = "l1"

resource_id = "045"
runs_id = "runs/xgb-045-trl5-5fold-s42"

threshold = "0.99"  # 0.90, 0.95, 0.99の中から選択

FEATURE_DIR = Path(f"../../artifacts/features/{ID}")

os.makedirs(FEATURE_DIR, exist_ok=True)

pl.Config.set_tbl_rows(500)
pl.Config.set_tbl_cols(500)

print(f"Feature dir created successfully in \n{FEATURE_DIR}")
# Out:
# Feature dir created successfully in
# ../../artifacts/features/047

# %% [markdown]
# ### Utils

# %%
def check_info(
    train: pl.DataFrame,
    test: pl.DataFrame
) -> tuple[float, float, float]:
    train_mem = sum(train[col].to_numpy().nbytes for col in train.columns) / 1024**3
    test_mem = sum(test[col].to_numpy().nbytes for col in test.columns) / 1024**3

    print("=== Shape & Memory ===")
    print(f"Train Shape: {train.shape}, Test Shape: {test.shape}")
    print(f"Train Memory: {train_mem:.2f} GB, Test Memory: {test_mem:.2f} GB\n")

    dtype_counts = Counter([str(dt) for dt in train.dtypes])

    n_cat = None
    print("=== DTypes ===")
    for dtype, cnt in dtype_counts.items():
        print(f"{dtype}: {cnt}")
        if dtype == "Categorical":
            n_cat = cnt
    return train_mem, test_mem, n_cat

# %% [markdown]
# ### Feature Engineering
# - 045を閾値99%でcolを選別

# %%
# === Load Data ===
resource_dir = Path(f"../../artifacts/features/{resource_id}")

with open(resource_dir / "meta.json", "r") as f:
    meta = json.load(f)

train_paths = meta["train_paths"]
test_paths = meta["test_paths"]

with open(f"../../{runs_id}/keep_cols.json", "r") as f:
    keep_cols = json.load(f)[threshold]["cols"]

all_cols = pl.read_parquet(train_paths, n_rows=0).columns

train_cols = keep_cols + ["target", "5fold-s42", "row_id"]

train = pl.read_parquet(train_paths, columns=train_cols)
test = pl.read_parquet(test_paths, columns=keep_cols)

# %%
# === 特徴量エンジニアリング後の情報 ===
train_mem, test_mem, n_cat = check_info(train, test)
# Out:
# === Shape & Memory ===
# Train Shape: (750000, 566), Test Shape: (250000, 563)
# Train Memory: 1.58 GB, Test Memory: 0.53 GB
#
# === DTypes ===
# Float32: 533
# Int32: 29
# Int64: 1
# Int8: 2
# UInt32: 1

# %%
# === Save Overall Data ===
tr_path = FEATURE_DIR / "train.parquet"
test_path = FEATURE_DIR / "test.parquet"

train.write_parquet(tr_path)
test.write_parquet(test_path)

print(f"tr_df saved successfully to {tr_path}")
print(f"test_df saved successfully to {test_path}")
# Out:
# tr_df saved successfully to ../../artifacts/features/047/train.parquet
# test_df saved successfully to ../../artifacts/features/047/test.parquet

# %% [markdown]
# ### Save Meta data

# %%
JST = timezone(timedelta(hours=9))
pairs = [
    ("skf/k=5/s=42@train", "5fold-s42")
]
meta = {
    "data_id": ID,
    "train_paths": [str(tr_path)],
    "test_paths": [str(test_path)],
    "level": level,
    "created_at": datetime.now(JST).isoformat(),
    "train_shape": [train.height, train.width],
    "test_shape": [test.height, test.width],
    "memory": {
        "train": train_mem,
        "test": test_mem
    },
    "fold_column": pairs,
    "cat_cols": n_cat if n_cat else None
}

with open(f"{FEATURE_DIR}/meta.json", "w", encoding="utf-8") as f:
    json.dump(meta, f, ensure_ascii=False, indent=2)

for k, v in meta.items():
    print(f"{k}: {v}")
# Out:
# data_id: 047
# train_paths: ['../../artifacts/features/047/train.parquet']
# test_paths: ['../../artifacts/features/047/test.parquet']
# level: l1
# created_at: 2025-10-03T17:08:40.126776+09:00
# train_shape: [750000, 566]
# test_shape: [250000, 563]
# memory: {'train': 1.5799887478351593, 'test': 0.5252659320831299}
# fold_column: [('skf/k=5/s=42@train', '5fold-s42')]
# cat_cols: None

# %%
for c in keep_cols:
    print(c)
# Out:
# target_mean_by_contact_duration2
# target_mean_by_housing_duration2
# target_mean_by_month_duration2
# target_mean_by_duration2_previous2
# target_mean_by_poutcome_duration2
# target_mean_by_month_day2
# target_median_by_poutcome_duration2
# target_std_by_contact_duration2
# target_mean_by_education_duration2
# target_std_by_month_day2
# target_mean_by_duration2_pdays2
# target_mean_by_marital_duration2
# target_mean_by_job_duration2
# target_mean_by_poutcome_balance2
# target_mean_by_contact_balance2
# target_std_by_housing_duration2
# target_mean_by_loan_balance2
# month_day2_ce
# target_mean_by_job_balance2
# target_std_by_month_duration2
# duration
# target_median_by_housing_duration2
# target_mean_by_marital_balance2
# target_mean_by_loan_duration2
# target_mean_by_month_pdays2
# target_std_by_contact_balance2
# target_mean_by_housing_balance2
# target_mean_by_contact_month
# duration_sq
# target_mean_by_education_balance2
# target_mean_by_month_poutcome
# age_div_duration
# target_std_by_poutcome_duration2
# target_median_by_month_day2
# target_median_by_month_poutcome
# target_std_by_contact_month
# target_mean_by_poutcome_pdays2
# target_std_by_job_duration2
# target_mean_by_balance2_duration2
# target_mean_by_default_balance2
# target_std_by_housing_balance2
# target_mean_by_housing_month
# target_mean_by_balance2_campaign2
# target_median_by_poutcome_balance2
# target_std_by_housing_month
# target_count_by_balance2_campaign2
# target_count_by_loan_balance2
# target_median_by_month_pdays2
# duration_div_campaign
# target_mean_by_month_balance2
# target_std_by_education_duration2
# age_mul_duration
# duration_div_pdays
# target_std_by_default_duration2
# target_std_by_loan_duration2
# target_std_by_marital_duration2
# target_mean_by_balance2_pdays2
# target_std_by_marital_balance2
# target_count_by_contact_balance2
# target_mean_by_age2_pdays2
# duration_median_by_balance2
# month_duration2_ce
# duration_mul_pdays
# target_mean_by_default_duration2
# target_mean_by_day2_pdays2
# poutcome_duration2_ce
# target_count_by_education_balance2
# target_mean_by_age2_balance2
# target_std_by_duration2_campaign2
# target_std_by_loan_balance2
# duration_div_previous
# previous_mean_by_balance2
# target_mean_by_housing_contact
# duration_mean_by_balance2
# balance_mul_duration
# age_std_by_balance2
# target_count_by_job_balance2
# target_mean_by_housing_poutcome
# target_mean_by_day2_duration2
# target_median_by_month_duration2
# target_std_by_month_pdays2
# previous_mean_by_duration2
# pdays_mean_by_balance2
# target_std_by_month_age2
# day2_duration2_ce
# target_std_by_month_poutcome
# target_count_by_month_day2
# day_std_by_duration2
# balance_div_duration
# target_std_by_education_balance2
# target_mean_by_housing_age2
# month_age2_ce
# target_std_by_contact_pdays2
# age_mean_by_duration2
# target_std_by_duration2_pdays2
# pdays_std_by_balance2
# campaign_mean_by_duration2
# balance_div_campaign
# day_std_by_balance2
# target_std_by_duration2_previous2
# target_mean_by_housing_pdays2
# target_std_by_job_balance2
# pdays_std_by_duration2
# target_mean_by_duration2_campaign2
# balance_mul_campaign
# pdays_mean_by_duration2
# target_std_by_age2_pdays2
# age_std_by_duration2
# target_mean_by_housing_campaign2
# duration_digitL2
# target_mean_by_month_age2
# day_div_duration
# target_mean_by_housing_day2
# day_mean_by_duration2
# previous_std_by_balance2
# target_count_by_month_duration2
# target_mean_by_loan_pdays2
# day_mul_duration
# target_mean_by_marital_age2
# target_count_by_month_campaign2
# day_mean_by_balance2
# target_mean_by_poutcome_age2
# target_mean_by_contact_day2
# previous_std_by_duration2
# balance_mean_by_duration2
# target_median_by_poutcome_pdays2
# target_count_by_job_age2
# age_mul_balance
# loan_month_ce
# balance_median_by_duration2
# contact_duration2_ce
# balance_std_by_duration2
# balance_div_previous
# age_mean_by_balance2
# target_count_by_housing_month
# age_div_balance
# target_count_by_marital_age2
# duration_std_by_balance2
# campaign_std_by_duration2
# marital_duration2_ce
# target_mean_by_job_age2
# balance_div_pdays
# campaign_mean_by_balance2
# target_std_by_balance2_campaign2
# duration_max_by_balance2
# target_median_by_contact_month
# campaign_std_by_balance2
# target_std_by_day2_duration2
# target_std_by_job_age2
# target_mean_by_balance2_previous2
# target_std_by_age2_duration2
# target_mean_by_age2_duration2
# target_mean_by_age2_day2
# balance2_duration2_ce
# balance
# target_count_by_housing_day2
# target_std_by_balance2_pdays2
# pdays_max_by_duration2
# age_div_day
# target_mean_by_campaign2_pdays2
# target_mean_by_education_age2
# target_std_by_month_balance2
# target_count_by_housing_balance2
# target_std_by_contact_day2
# target_count_by_education_month
# balance_mul_pdays
# target_count_by_loan_month
# target_mean_by_age2_campaign2
# target_std_by_age2_day2
# target_mean_by_contact_pdays2
# pdays_max_by_balance2
# target_count_by_poutcome_duration2
# target_mean_by_job_pdays2
# balance_div_day
# target_std_by_day2_campaign2
# target_count_by_housing_duration2
# balance_mul_day
# target_count_by_contact_month
# duration_mul_campaign
# age_mul_campaign
# housing_duration2_ce
# target_count_by_housing_age2
# target_mean_by_job_day2
# balance_sq
# target_count_by_month_age2
# target_std_by_job_month
# target_mean_by_marital_day2
# age_mul_day
# target_count_by_age2_day2
# target_count_by_job_day2
# marital_balance2_ce
# target_count_by_job_month
# target_mean_by_day2_campaign2
# target_count_by_contact_day2
# target_std_by_age2_campaign2
# target_count_by_job_education
# age2_day2_ce
# target_std_by_housing_age2
# target_std_by_housing_campaign2
# target_count_by_marital_duration2
# target_count_by_education_duration2
# job_balance2_ce
# target_std_by_age2_balance2
# target_std_by_default_balance2
# target_count_by_education_age2
# default_duration2_ce
# target_count_by_marital_day2
# target_mean_by_education_day2
# target_std_by_job_day2
# target_mean_by_month_campaign2
# target_count_by_age2_campaign2
# target_mean_by_loan_contact
# target_count_by_age2_balance2
# target_mean_by_job_month
# target_count_by_job_duration2
# target_std_by_month_campaign2
# age2_duration2_ce
# target_std_by_marital_age2
# day_div_campaign
# target_std_by_housing_loan
# target_std_by_balance2_day2
# previous_max_by_duration2
# target_count_by_day2_campaign2
# balance_max_by_duration2
# age_mean_by_day2
# duration2_previous2_ce
# month_balance2_ce
# job_duration2_ce
# job_day2_ce
# target_mean_by_contact_age2
# target_std_by_balance2_previous2
# target_std_by_housing_day2
# target_mean_by_loan_day2
# target_std_by_poutcome_balance2
# target_mean_by_balance2_day2
# age2_balance2_ce
# target_count_by_job_campaign2
# day_median_by_month
# target_count_by_loan_age2
# target_count_by_education_day2
# target_count_by_duration2_campaign2
# campaign_max_by_duration2
# marital_age2_ce
# target_count_by_marital_balance2
# contact_month_ce
# job_age2_ce
# target_mean_by_marital_campaign2
# target_std_by_education_age2
# education_balance2_ce
# loan_balance2_ce
# duration_max_by_age2
# age_median_by_balance2
# pdays_std_by_age2
# target_count_by_job_marital
# balance2_campaign2_ce
# housing_day2_ce
# age_div_campaign
# balance_digitL0
# target_count_by_contact_duration2
# target_std_by_day2_pdays2
# target_count_by_marital_month
# balance2_day2_ce
# target_count_by_job_housing
# campaign_max_by_balance2
# education_day2_ce
# month_campaign2_ce
# pdays_mean_by_age2
# education_duration2_ce
# target_mean_by_job_contact
# target_count_by_default_duration2
# target_mean_by_contact_campaign2
# target_count_by_job_contact
# marital_day2_ce
# target_count_by_duration2_pdays2
# age2_campaign2_ce
# age_max_by_balance2
# day2_campaign2_ce
# target_mean_by_education_campaign2
# duration_std_by_day2
# target_median_by_poutcome_age2
# target_std_by_job_housing
# target_count_by_contact_age2
# housing_balance2_ce
# target_mean_by_loan_age2
# target_count_by_default_balance2
# duration2_campaign2_ce
# age_max_by_duration2
# target_mean_by_job_education
# target_mean_by_job_poutcome
# target_count_by_loan_duration2
# target_std_by_loan_day2
# target_std_by_poutcome_age2
# target_std_by_job_contact
# duration_digitL1
# target_mean_by_job_housing
# target_mean_by_marital_month
# education_age2_ce
# target_std_by_contact_age2
# previous_std_by_age2
# duration_mean_by_month
# target_count_by_duration2_previous2
# previous_max_by_balance2
# day_std_by_age2
# target_count_by_loan_day2
# contact_day2_ce
# target_count_by_poutcome_day2
# housing_age2_ce
# balance_digitL2
# duration_std_by_age2
# contact_balance2_ce
# target_count_by_job_loan
# target_mean_by_job_campaign2
# day_std_by_month
# target_mean_by_job_marital
# balance_digitL1
# target_std_by_balance2_duration2
# target_mean_by_education_month
# campaign_mean_by_day2
# target_std_by_education_day2
# target_std_by_marital_month
# duration_mean_by_day2
# campaign_std_by_age2
# target_count_by_marital_education
# target_std_by_marital_day2
# target_mean_by_marital_pdays2
# target_std_by_marital_campaign2
# target_count_by_poutcome_age2
# day_sin
# default_balance2_ce
# loan_duration2_ce
# target_count_by_marital_campaign2
# target_std_by_job_campaign2
# target_mean_by_loan_campaign2
# duration_digitL0
# poutcome_balance2_ce
# age2_previous2_ce
# job_month_ce
# target_count_by_month_balance2
# target_count_by_day2_duration2
# day_mul_campaign
# campaign_mean_by_age2
# previous_max_by_day2
# target_std_by_loan_age2
# target_count_by_education_campaign2
# target_std_by_housing_pdays2
# day_mean_by_age2
# target_mean_by_age2_previous2
# target_count_by_poutcome_balance2
# education_month_ce
# pdays_max_by_age2
# target_mean_by_default_month
# day_mean_by_month
# duration_max_by_day2
# age_median_by_duration2
# loan_day2_ce
# target_count_by_default_day2
# target_mean_by_poutcome_campaign2
# target_std_by_age2_previous2
# balance2_pdays2_ce
# poutcome_age2_ce
# balance_std_by_age2
# campaign_std_by_day2
# duration2_pdays2_ce
# age_std_by_day2
# target_mean_by_marital_education
# target_count_by_balance2_previous2
# duration_std_by_month
# target_median_by_contact_duration2
# balance_max_by_month
# previous_mean_by_age2
# target_count_by_age2_duration2
# balance_mean_by_age2
# target_count_by_balance2_pdays2
# target_std_by_job_pdays2
# month_cos
# balance_median_by_day2
# target_count_by_job_poutcome
# job_campaign2_ce
# target_mean_by_default_day2
# target_std_by_job_marital
# target_count_by_default_age2
# target_count_by_day2_pdays2
# target_std_by_education_month
# campaign_max_by_month
# job_education_ce
# contact_age2_ce
# target_count_by_month_poutcome
# target_mean_by_education_housing
# pdays_max_by_day2
# target_median_by_balance2_duration2
# target_std_by_education_campaign2
# balance_median_by_age2
# target_mean_by_poutcome_day2
# balance2_previous2_ce
# target_median_by_job_balance2
# target_std_by_loan_contact
# target_count_by_loan_campaign2
# target_count_by_marital_housing
# target_std_by_contact_campaign2
# target_count_by_age2_pdays2
# target_mean_by_month_previous2
# balance_mean_by_day2
# duration_mean_by_age2
# target_count_by_marital_loan
# target_std_by_marital_pdays2
# target_std_by_loan_pdays2
# housing_month_ce
# loan_campaign2_ce
# target_std_by_job_education
# age_div_pdays
# previous_max_by_age2
# target_std_by_default_month
# pdays_mean_by_day2
# target_mean_by_marital_housing
# target_count_by_education_contact
# loan_age2_ce
# target_std_by_campaign2_pdays2
# day2_pdays2_ce
# target_mean_by_job_loan
# day_div_pdays
# day_median_by_balance2
# age_mean_by_month
# target_count_by_education_poutcome
# previous_std_by_day2
# target_std_by_month_previous2
# pdays_std_by_day2
# target_mean_by_default_age2
# target_std_by_day2_previous2
# target_mean_by_marital_contact
# pdays_mean_by_job
# target_std_by_poutcome_day2
# campaign_max_by_age2
# target_count_by_education_loan
# target_count_by_age2_previous2
# age
# target_mean_by_day2_previous2
# target_count_by_default_month
# duration_median_by_age2
# target_count_by_month_pdays2
# target_std_by_loan_campaign2
# target_mean_by_loan_month
# balance_digitL3
# target_mean_by_education_contact
# age_mean_by_job
# job_marital_ce
# month_pdays2_ce
# pdays_std_by_month
# target_count_by_contact_campaign2
# target_std_by_default_age2
# target_count_by_education_housing
# marital_month_ce
# age2_pdays2_ce
# target_count_by_housing_contact
# housing_contact_ce
# day_cos
# target_mean_by_default_pdays2
# balance_std_by_day2
# age_mul_pdays
# target_std_by_marital_education
# age_median_by_day2
# target_median_by_job_duration2
# campaign_mean_by_month
# day
# campaign_std_by_month
# target_median_by_default_poutcome
# target_std_by_default_day2
# poutcome_day2_ce
# default_age2_ce
# day_mul_pdays
# day_median_by_duration2
# target_count_by_poutcome_campaign2
# target_count_by_marital_contact
# target_median_by_contact_balance2
# target_std_by_job_poutcome
# target_std_by_education_pdays2
# target_mean_by_education_pdays2
# target_count_by_housing_campaign2
# duration_median_by_day2
# target_count_by_day2_previous2
# age_std_by_month
# target_count_by_marital_poutcome
# previous_mean_by_day2
# target_median_by_age2_balance2
# day_div_previous
# target_std_by_loan_month
# target_count_by_contact_poutcome
# target_std_by_poutcome_pdays2
# target_mean_by_marital_loan
# age_max_by_day2
# target_mean_by_job_previous2
# balance_max_by_day2
# marital_education_ce
# target_count_by_job_default
# target_std_by_job_loan
# balance_max_by_age2
# default_day2_ce
# target_std_by_marital_contact
# target_count_by_campaign2_pdays2
# target_count_by_balance2_day2
# target_std_by_education_contact
# target_std_by_education_housing
# target_std_by_job_previous2
# campaign_max_by_day2
# age_std_by_pdays2
# target_mean_by_housing_previous2
# target_count_by_month_previous2
# target_count_by_marital_pdays2
# target_mean_by_housing_loan
# target_count_by_housing_poutcome
# target_std_by_marital_housing
# target_count_by_job_pdays2
# target_count_by_loan_poutcome
# duration_std_by_job
# target_mean_by_education_loan
# target_mean_by_marital_poutcome
# age_sq
# job_contact_ce
# target_count_by_campaign2_previous2
# job_loan_ce
# target_count_by_marital_default
# target_count_by_balance2_duration2
# target_mean_by_job_default
# target_mean_by_education_poutcome
# duration_mean_by_job
# target_mean_by_pdays2_previous2
# target_std_by_housing_previous2
# target_count_by_education_pdays2
# education_campaign2_ce
# job_housing_ce
# duration_digitL3
# day_sq
# age_div_previous
# target_count_by_job_previous2
# target_std_by_housing_contact
# target_median_by_day2_duration2
# marital_campaign2_ce
# target_count_by_housing_pdays2
# target_count_by_housing_loan
# contact_campaign2_ce
# target_count_by_education_previous2
# day2_previous2_ce
# marital_loan_ce
# pdays_max_by_month
# target_count_by_contact_pdays2
# previous_std_by_pdays2
# age_std_by_job
# target_median_by_housing_pdays2
# previous_max_by_pdays2
# target_mean_by_education_default
# target_std_by_housing_poutcome
# target_std_by_contact_previous2
# balance_std_by_month
# education_loan_ce
# target_count_by_education_default
# previous_std_by_month
# day_std_by_job
# duration_max_by_month
# target_mean_by_education_previous2
# target_std_by_education_poutcome
# target_std_by_job_default
# target_std_by_marital_loan
# target_std_by_pdays2_previous2
# pdays_mean_by_month

# %%
for i, c in enumerate(keep_cols):
    if "target" in c:
        print(i, c)
# Out:
# 0 target_mean_by_contact_duration2
# 1 target_mean_by_housing_duration2
# 2 target_mean_by_month_duration2
# 3 target_mean_by_duration2_previous2
# 4 target_mean_by_poutcome_duration2
# 5 target_mean_by_month_day2
# 6 target_median_by_poutcome_duration2
# 7 target_std_by_contact_duration2
# 8 target_mean_by_education_duration2
# 9 target_std_by_month_day2
# 10 target_mean_by_duration2_pdays2
# 11 target_mean_by_marital_duration2
# 12 target_mean_by_job_duration2
# 13 target_mean_by_poutcome_balance2
# 14 target_mean_by_contact_balance2
# 15 target_std_by_housing_duration2
# 16 target_mean_by_loan_balance2
# 18 target_mean_by_job_balance2
# 19 target_std_by_month_duration2
# 21 target_median_by_housing_duration2
# 22 target_mean_by_marital_balance2
# 23 target_mean_by_loan_duration2
# 24 target_mean_by_month_pdays2
# 25 target_std_by_contact_balance2
# 26 target_mean_by_housing_balance2
# 27 target_mean_by_contact_month
# 29 target_mean_by_education_balance2
# 30 target_mean_by_month_poutcome
# 32 target_std_by_poutcome_duration2
# 33 target_median_by_month_day2
# 34 target_median_by_month_poutcome
# 35 target_std_by_contact_month
# 36 target_mean_by_poutcome_pdays2
# 37 target_std_by_job_duration2
# 38 target_mean_by_balance2_duration2
# 39 target_mean_by_default_balance2
# 40 target_std_by_housing_balance2
# 41 target_mean_by_housing_month
# 42 target_mean_by_balance2_campaign2
# 43 target_median_by_poutcome_balance2
# 44 target_std_by_housing_month
# 45 target_count_by_balance2_campaign2
# 46 target_count_by_loan_balance2
# 47 target_median_by_month_pdays2
# 49 target_mean_by_month_balance2
# 50 target_std_by_education_duration2
# 53 target_std_by_default_duration2
# 54 target_std_by_loan_duration2
# 55 target_std_by_marital_duration2
# 56 target_mean_by_balance2_pdays2
# 57 target_std_by_marital_balance2
# 58 target_count_by_contact_balance2
# 59 target_mean_by_age2_pdays2
# 63 target_mean_by_default_duration2
# 64 target_mean_by_day2_pdays2
# 66 target_count_by_education_balance2
# 67 target_mean_by_age2_balance2
# 68 target_std_by_duration2_campaign2
# 69 target_std_by_loan_balance2
# 72 target_mean_by_housing_contact
# 76 target_count_by_job_balance2
# 77 target_mean_by_housing_poutcome
# 78 target_mean_by_day2_duration2
# 79 target_median_by_month_duration2
# 80 target_std_by_month_pdays2
# 83 target_std_by_month_age2
# 85 target_std_by_month_poutcome
# 86 target_count_by_month_day2
# 89 target_std_by_education_balance2
# 90 target_mean_by_housing_age2
# 92 target_std_by_contact_pdays2
# 94 target_std_by_duration2_pdays2
# 99 target_std_by_duration2_previous2
# 100 target_mean_by_housing_pdays2
# 101 target_std_by_job_balance2
# 103 target_mean_by_duration2_campaign2
# 106 target_std_by_age2_pdays2
# 108 target_mean_by_housing_campaign2
# 110 target_mean_by_month_age2
# 112 target_mean_by_housing_day2
# 115 target_count_by_month_duration2
# 116 target_mean_by_loan_pdays2
# 118 target_mean_by_marital_age2
# 119 target_count_by_month_campaign2
# 121 target_mean_by_poutcome_age2
# 122 target_mean_by_contact_day2
# 125 target_median_by_poutcome_pdays2
# 126 target_count_by_job_age2
# 134 target_count_by_housing_month
# 136 target_count_by_marital_age2
# 140 target_mean_by_job_age2
# 143 target_std_by_balance2_campaign2
# 145 target_median_by_contact_month
# 147 target_std_by_day2_duration2
# 148 target_std_by_job_age2
# 149 target_mean_by_balance2_previous2
# 150 target_std_by_age2_duration2
# 151 target_mean_by_age2_duration2
# 152 target_mean_by_age2_day2
# 155 target_count_by_housing_day2
# 156 target_std_by_balance2_pdays2
# 159 target_mean_by_campaign2_pdays2
# 160 target_mean_by_education_age2
# 161 target_std_by_month_balance2
# 162 target_count_by_housing_balance2
# 163 target_std_by_contact_day2
# 164 target_count_by_education_month
# 166 target_count_by_loan_month
# 167 target_mean_by_age2_campaign2
# 168 target_std_by_age2_day2
# 169 target_mean_by_contact_pdays2
# 171 target_count_by_poutcome_duration2
# 172 target_mean_by_job_pdays2
# 174 target_std_by_day2_campaign2
# 175 target_count_by_housing_duration2
# 177 target_count_by_contact_month
# 181 target_count_by_housing_age2
# 182 target_mean_by_job_day2
# 184 target_count_by_month_age2
# 185 target_std_by_job_month
# 186 target_mean_by_marital_day2
# 188 target_count_by_age2_day2
# 189 target_count_by_job_day2
# 191 target_count_by_job_month
# 192 target_mean_by_day2_campaign2
# 193 target_count_by_contact_day2
# 194 target_std_by_age2_campaign2
# 195 target_count_by_job_education
# 197 target_std_by_housing_age2
# 198 target_std_by_housing_campaign2
# 199 target_count_by_marital_duration2
# 200 target_count_by_education_duration2
# 202 target_std_by_age2_balance2
# 203 target_std_by_default_balance2
# 204 target_count_by_education_age2
# 206 target_count_by_marital_day2
# 207 target_mean_by_education_day2
# 208 target_std_by_job_day2
# 209 target_mean_by_month_campaign2
# 210 target_count_by_age2_campaign2
# 211 target_mean_by_loan_contact
# 212 target_count_by_age2_balance2
# 213 target_mean_by_job_month
# 214 target_count_by_job_duration2
# 215 target_std_by_month_campaign2
# 217 target_std_by_marital_age2
# 219 target_std_by_housing_loan
# 220 target_std_by_balance2_day2
# 222 target_count_by_day2_campaign2
# 229 target_mean_by_contact_age2
# 230 target_std_by_balance2_previous2
# 231 target_std_by_housing_day2
# 232 target_mean_by_loan_day2
# 233 target_std_by_poutcome_balance2
# 234 target_mean_by_balance2_day2
# 236 target_count_by_job_campaign2
# 238 target_count_by_loan_age2
# 239 target_count_by_education_day2
# 240 target_count_by_duration2_campaign2
# 243 target_count_by_marital_balance2
# 246 target_mean_by_marital_campaign2
# 247 target_std_by_education_age2
# 253 target_count_by_job_marital
# 258 target_count_by_contact_duration2
# 259 target_std_by_day2_pdays2
# 260 target_count_by_marital_month
# 262 target_count_by_job_housing
# 268 target_mean_by_job_contact
# 269 target_count_by_default_duration2
# 270 target_mean_by_contact_campaign2
# 271 target_count_by_job_contact
# 273 target_count_by_duration2_pdays2
# 277 target_mean_by_education_campaign2
# 279 target_median_by_poutcome_age2
# 280 target_std_by_job_housing
# 281 target_count_by_contact_age2
# 283 target_mean_by_loan_age2
# 284 target_count_by_default_balance2
# 287 target_mean_by_job_education
# 288 target_mean_by_job_poutcome
# 289 target_count_by_loan_duration2
# 290 target_std_by_loan_day2
# 291 target_std_by_poutcome_age2
# 292 target_std_by_job_contact
# 294 target_mean_by_job_housing
# 295 target_mean_by_marital_month
# 297 target_std_by_contact_age2
# 300 target_count_by_duration2_previous2
# 303 target_count_by_loan_day2
# 305 target_count_by_poutcome_day2
# 310 target_count_by_job_loan
# 311 target_mean_by_job_campaign2
# 313 target_mean_by_job_marital
# 315 target_std_by_balance2_duration2
# 316 target_mean_by_education_month
# 318 target_std_by_education_day2
# 319 target_std_by_marital_month
# 322 target_count_by_marital_education
# 323 target_std_by_marital_day2
# 324 target_mean_by_marital_pdays2
# 325 target_std_by_marital_campaign2
# 326 target_count_by_poutcome_age2
# 330 target_count_by_marital_campaign2
# 331 target_std_by_job_campaign2
# 332 target_mean_by_loan_campaign2
# 337 target_count_by_month_balance2
# 338 target_count_by_day2_duration2
# 342 target_std_by_loan_age2
# 343 target_count_by_education_campaign2
# 344 target_std_by_housing_pdays2
# 346 target_mean_by_age2_previous2
# 347 target_count_by_poutcome_balance2
# 350 target_mean_by_default_month
# 355 target_count_by_default_day2
# 356 target_mean_by_poutcome_campaign2
# 357 target_std_by_age2_previous2
# 364 target_mean_by_marital_education
# 365 target_count_by_balance2_previous2
# 367 target_median_by_contact_duration2
# 370 target_count_by_age2_duration2
# 372 target_count_by_balance2_pdays2
# 373 target_std_by_job_pdays2
# 376 target_count_by_job_poutcome
# 378 target_mean_by_default_day2
# 379 target_std_by_job_marital
# 380 target_count_by_default_age2
# 381 target_count_by_day2_pdays2
# 382 target_std_by_education_month
# 386 target_count_by_month_poutcome
# 387 target_mean_by_education_housing
# 389 target_median_by_balance2_duration2
# 390 target_std_by_education_campaign2
# 392 target_mean_by_poutcome_day2
# 394 target_median_by_job_balance2
# 395 target_std_by_loan_contact
# 396 target_count_by_loan_campaign2
# 397 target_count_by_marital_housing
# 398 target_std_by_contact_campaign2
# 399 target_count_by_age2_pdays2
# 400 target_mean_by_month_previous2
# 403 target_count_by_marital_loan
# 404 target_std_by_marital_pdays2
# 405 target_std_by_loan_pdays2
# 408 target_std_by_job_education
# 411 target_std_by_default_month
# 413 target_mean_by_marital_housing
# 414 target_count_by_education_contact
# 416 target_std_by_campaign2_pdays2
# 418 target_mean_by_job_loan
# 422 target_count_by_education_poutcome
# 424 target_std_by_month_previous2
# 426 target_mean_by_default_age2
# 427 target_std_by_day2_previous2
# 428 target_mean_by_marital_contact
# 430 target_std_by_poutcome_day2
# 432 target_count_by_education_loan
# 433 target_count_by_age2_previous2
# 435 target_mean_by_day2_previous2
# 436 target_count_by_default_month
# 438 target_count_by_month_pdays2
# 439 target_std_by_loan_campaign2
# 440 target_mean_by_loan_month
# 442 target_mean_by_education_contact
# 447 target_count_by_contact_campaign2
# 448 target_std_by_default_age2
# 449 target_count_by_education_housing
# 452 target_count_by_housing_contact
# 455 target_mean_by_default_pdays2
# 458 target_std_by_marital_education
# 460 target_median_by_job_duration2
# 464 target_median_by_default_poutcome
# 465 target_std_by_default_day2
# 470 target_count_by_poutcome_campaign2
# 471 target_count_by_marital_contact
# 472 target_median_by_contact_balance2
# 473 target_std_by_job_poutcome
# 474 target_std_by_education_pdays2
# 475 target_mean_by_education_pdays2
# 476 target_count_by_housing_campaign2
# 478 target_count_by_day2_previous2
# 480 target_count_by_marital_poutcome
# 482 target_median_by_age2_balance2
# 484 target_std_by_loan_month
# 485 target_count_by_contact_poutcome
# 486 target_std_by_poutcome_pdays2
# 487 target_mean_by_marital_loan
# 489 target_mean_by_job_previous2
# 492 target_count_by_job_default
# 493 target_std_by_job_loan
# 496 target_std_by_marital_contact
# 497 target_count_by_campaign2_pdays2
# 498 target_count_by_balance2_day2
# 499 target_std_by_education_contact
# 500 target_std_by_education_housing
# 501 target_std_by_job_previous2
# 504 target_mean_by_housing_previous2
# 505 target_count_by_month_previous2
# 506 target_count_by_marital_pdays2
# 507 target_mean_by_housing_loan
# 508 target_count_by_housing_poutcome
# 509 target_std_by_marital_housing
# 510 target_count_by_job_pdays2
# 511 target_count_by_loan_poutcome
# 513 target_mean_by_education_loan
# 514 target_mean_by_marital_poutcome
# 517 target_count_by_campaign2_previous2
# 519 target_count_by_marital_default
# 520 target_count_by_balance2_duration2
# 521 target_mean_by_job_default
# 522 target_mean_by_education_poutcome
# 524 target_mean_by_pdays2_previous2
# 525 target_std_by_housing_previous2
# 526 target_count_by_education_pdays2
# 532 target_count_by_job_previous2
# 533 target_std_by_housing_contact
# 534 target_median_by_day2_duration2
# 536 target_count_by_housing_pdays2
# 537 target_count_by_housing_loan
# 539 target_count_by_education_previous2
# 543 target_count_by_contact_pdays2
# 546 target_median_by_housing_pdays2
# 548 target_mean_by_education_default
# 549 target_std_by_housing_poutcome
# 550 target_std_by_contact_previous2
# 553 target_count_by_education_default
# 557 target_mean_by_education_previous2
# 558 target_std_by_education_poutcome
# 559 target_std_by_job_default
# 560 target_std_by_marital_loan
# 561 target_std_by_pdays2_previous2

# %%
# src/tuning/optuna_objectives.py
"""
Unified Optuna objective factory and model registry.

- One-stop place to define search spaces and bind them to Trainer classes.
- Add a model by registering: ("module.path:TrainerClass", search_space_fn, tags)
"""

from __future__ import annotations
from typing import Callable, Any, Type
import importlib
import json
from pathlib import Path

import optuna
import wandb
from optuna.exceptions import TrialPruned

from src.utils.snapshot_study import snapshot_study
from src.utils.telegram import send_message
from src.utils.loggers import WandbLogger

# ---- Types ----
Objective          = Callable[[optuna.trial.Trial], float]
ObjectiveFactory   = Callable[..., Objective]
SearchSpace        = Callable[[optuna.trial.Trial], dict[str, Any]]
TrainerSpec        = str  # "module.path:ClassName"

def _resolve(spec: TrainerSpec) -> Type:
    mod, name = spec.split(":")
    return getattr(importlib.import_module(mod), name)

# ---- Search spaces per model (差分はここだけ) ----


def space_lgbm(t: optuna.trial.Trial) -> dict[str, Any]:
    return {
        "learning_rate": 0.02,
        "num_leaves":   t.suggest_int("num_leaves", 31, 511),
        "max_depth":    t.suggest_int("max_depth", -1, 12),
        "min_data_in_leaf": t.suggest_int("min_data_in_leaf", 10, 200),
        "feature_fraction": t.suggest_float("feature_fraction", 0.6, 0.95),
        "bagging_fraction": t.suggest_float("bagging_fraction", 0.6, 0.95),
        "bagging_freq":     t.suggest_int("bagging_freq", 0, 10),
        "lambda_l1":  t.suggest_float("lambda_l1", 1e-4, 20.0, log=True),
        "lambda_l2":  t.suggest_float("lambda_l2", 1e-4, 20.0, log=True),
    }

# 必要に応じて追加: space_cb, space_tabnet, ...

# ---- Registry: model_name -> (Trainer class spec, search space fn, tags) ----
_REGISTRY: dict[str, tuple[TrainerSpec, SearchSpace, list[str]]] = {
    "xgb":  ("src.models.xgb.xgb_cv_trainer:XGBCVTrainer",   space_xgb,  ["xgb"]),
    "lgbm": ("src.models.lgbm.lgbm_cv_trainer:LGBMCVTrainer", space_lgbm, ["lgbm"]),
    # "cb":   ("src.models.cb.cb_cv_trainer:CBCVTrainer", space_cb, ["cb"]),
    # ...
}

def available_models() -> list[str]:
    return sorted(_REGISTRY)

# ---- Unified objective factory ----
def create_objective(
    model_type: str,
    data_id: int,
    *,
    seed: int = 42,
    n_folds: int = 5,
    fold_idx: int = 0,
    wandb_project: str = "project",
    study_name: str = "study",
    opts: dict | None = None,
    snapshot_every: int = 10,
) -> Objective:
    """
    Return Optuna objective(trial)->float for a given `model_type`.

    - Uses `_REGISTRY` to lazily import the corresponding Trainer class
      and to build its hyperparameter dict from `search_space(trial)`.
    - Common behaviors (W&B logging, manifest dump, pruning on OOM, snapshots)
      are centralized here.
    """
    try:
        trainer_spec, space_fn, tags = _REGISTRY[model_type]
    except KeyError:
        raise ValueError(f"Unknown model type: {model_type}. Available: {', '.join(available_models())}")

    Trainer = _resolve(trainer_spec)
    optuna_root = Path("../../artifacts/optuna")

    # features meta (共通。必要に応じてパスは調整)
    with open(f"../../artifacts/features/{data_id}/meta.json") as f:
        meta = json.load(f)
    train_paths = meta["train_paths"]
    level = meta.get("level", "unknown")

    def objective(trial: optuna.trial.Trial) -> float:
        params = space_fn(trial)

        run = wandb.init(
            project=wandb_project,
            group=study_name,
            name=f"trl{trial.number}",
            job_type="optuna-search",
            config={"data_id": data_id, "n_folds": n_folds, "level": level,
                    "model": model_type, **params, **(opts or {})},
            tags=[model_type, level, *tags],
            reinit=True,
            dir="../../artifacts",
        )

        try:
            trainer = Trainer(
                data_id,
                train_paths,
                n_folds=n_folds,
                params=params,
                seed=seed,
                opts=opts,
            )
            score = trainer.fit_one_fold(fold_idx, loggers=[WandbLogger(run=run)])

            (optuna_root / study_name).mkdir(parents=True, exist_ok=True)
            path = optuna_root / f"{study_name}/trl{trial.number}.json"
            manifest = {
                "params": params, "n_folds": n_folds, "seed": seed, "fold_idx": fold_idx,
                "wandb_id": run.id, "wandb_url": run.url, "opts": opts, "score": score,
            }
            with open(path, "w") as f:
                json.dump(manifest, f, indent=4)

            if snapshot_every and (trial.number + 1) % snapshot_every == 0:
                try:
                    snapshot_study(
                        study=trial.study,
                        study_name=study_name,
                        trial_num=trial.number,
                        out_root=optuna_root,
                        send_telegram=True,
                    )
                except Exception:
                    pass

            return score

        except RuntimeError as e:
            msg = str(e)
            if "CUDA out of memory" in msg:
                send_message(f"[OOM] study={study_name} tr={trial.number} params={trial.params}")
                raise TrialPruned("OOM -> pruned")
            else:
                send_message(f"[ERROR] study={study_name} tr={trial.number} {type(e).__name__}: {msg}")
                raise
        finally:
            wandb.finish()

    return objective
